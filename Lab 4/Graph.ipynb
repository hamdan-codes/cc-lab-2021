# %%
import matplotlib.pyplot as plt

# %%
service_broker_policy = ['Closest Data Center', 'Optimise Response Time', 'Reconfigure Dynamically with L']
load_balancing_policy = ['Round Robbin', 'Equally SpreadCurrent Execution Load', 'Throttled']

# %%
x = [f'{service_broker_policy[i]} -> {load_balancing_policy[j]}' for i in range(3) for j in range(3)]
x
# Out:
# ['Closest Data Center -> Round Robbin',
#  'Closest Data Center -> Equally SpreadCurrent Execution Load',
#  'Closest Data Center -> Throttled',
#  'Optimise Response Time -> Round Robbin',
#  'Optimise Response Time -> Equally SpreadCurrent Execution Load',
#  'Optimise Response Time -> Throttled',
#  'Reconfigure Dynamically with L -> Round Robbin',
#  'Reconfigure Dynamically with L -> Equally SpreadCurrent Execution Load',
#  'Reconfigure Dynamically with L -> Throttled']

# %%
y = [151.68, 151.69, 151.66, 
    151.78, 151.66, 151.50, 
    154.35, 152.20, 152.22, 
    ]

# %%
plt.xlabel('Service Broker Policy -> load_balancing_policy ------>')
plt.ylabel('Avg Response Time (in ms) ------>')
plt.xticks(rotation=90)
plt.plot(x, y)
plt.show()
