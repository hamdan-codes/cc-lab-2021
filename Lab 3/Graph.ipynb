# %%
import matplotlib.pyplot as plt

# %%
x = ['0', '1', '2', '3', '4', '5']
y = [50.1, 200.1, 300.1, 500.0, 500.0, 200.1]

plt.xlabel('Region ------>')
plt.ylabel('Avg Response Time (in ms) ------>')

plt.plot(x, y)
plt.show()
